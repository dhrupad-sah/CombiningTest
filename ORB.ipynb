# %%
import cv2 as cv
import matplotlib.pyplot as plt

# %%
img = cv.imread('shapes.png')
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)

# %%
orb = cv.ORB_create(75)

# %%
kp = orb.detect(img,None)

# %%
kp, des = orb.compute(img, kp)

# %%
img2 = cv.drawKeypoints(img, kp, None, color=(0,255,0), flags=0)
plt.imshow(img2), plt.show()
# Out:
# (<matplotlib.image.AxesImage at 0x138ecd35150>, None)

# %%
des
# Out:
# array([[130,  12,   2, ...,  10,  48, 128],
#        [  6,  12,   2, ...,  10,  48, 128],
#        [  0, 140,   2, ...,  10,  48, 128],
#        ...,
#        [ 35, 160,   5, ...,   8, 176, 168],
#        [  8, 143,   2, ...,  14,  56, 140],
#        [  0, 156,  25, ...,   8, 145, 170]], dtype=uint8)

# %%
import numpy as np
des_np = np.array(des)
des_flattened = des_np.flatten()

des_flattened.shape
# Out:
# (2048,)
